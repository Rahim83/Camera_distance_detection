# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]



target_class = "person"

# Known parameters (example values, you need to measure these)
real_width = 0.5   # meters, adjust this to the actual width of the target object      
known_distance = 2.0  # meters, the distance at which the known_width_in_image was measured
known_width_in_image = 200  # pixels, the width of the object in the image at known_distance

# Calculate the focal length
focal_length = (known_width_in_image * known_distance) / real_width


while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            
            # class name
            
            cls = int(box.cls[0])
            class_name = classNames[cls]

            if class_name == target_class:
                
            
                # bounding box
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

                # calculate the width of the bounding box in pixels
                width_in_image = x2 - x1

                # estimate the distance to the object
                distance = (real_width * focal_length) / width_in_image
    
                # put box in cam
                cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)
    
                # confidence
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confidence --->",confidence)
                print("classnamw is  --->",class_name)
                print("Estimated distance -->", distance, "meters")
    
                # object details
                org = [x1, y1]
                font = cv2.FONT_HERSHEY_SIMPLEX
                fontScale = 1
                color = (255, 0, 0)
                thickness = 2
    
                 #cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)
                cv2.putText(img, f"{class_name} {distance:.2f}m", org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 1 bed, 467.9ms
# Confidence ---> 0.79
# classnamw is  ---> person
# Estimated distance --> 0.6993006993006993 meters
# Speed: 8.5ms preprocess, 467.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 189.2ms
# Confidence ---> 0.86
# classnamw is  ---> person
# Estimated distance --> 0.631911532385466 meters
# Speed: 2.2ms preprocess, 189.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 171.5ms
# Confidence ---> 0.85
# classnamw is  ---> person
# Estimated distance --> 0.6379585326953748 meters
# Speed: 5.7ms preprocess, 171.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.0ms
# Confidence ---> 0.88
# classnamw is  ---> person
# Estimated distance --> 0.6589785831960461 meters
# Speed: 5.3ms preprocess, 172.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 171.0ms
# Confidence ---> 0.85
# classnamw is  ---> person
# Estimated distance --> 0.6451612903225806 meters
# Speed: 4.1ms preprocess, 171.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 176.8ms
# Confidence ---> 0.82
# classnamw is  ---> person
# Estimated distance --> 0.6688963210702341 meters
# Speed: 7.4ms preprocess, 176.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.7ms
# Confidence ---> 0.88
# classnamw is  ---> person
# Estimated distance --> 0.6734006734006734 meters
# Speed: 6.0ms preprocess, 180.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 188.5ms
# Confidence ---> 0.78
# classnamw is  ---> person
# Estimated distance --> 0.6309148264984227 meters
# Speed: 4.7ms preprocess, 188.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.0ms
# Confidence ---> 0.78
# classnamw is  ---> person
# Estimated distance --> 0.6644518272425249 meters
# Speed: 2.7ms preprocess, 174.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 171.6ms
# Confidence ---> 0.63
# classnamw is  ---> person
# Estimated distance --> 0.6980802792321117 meters
# Speed: 3.7ms preprocess, 171.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.3ms
# Confidence ---> 0.77
# classnamw is  ---> person
# Estimated distance --> 0.7117437722419929 meters
# Speed: 0.0ms preprocess, 178.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.6ms
# Confidence ---> 0.66
# classnamw is  ---> person
# Estimated distance --> 0.8032128514056225 meters
# Speed: 2.3ms preprocess, 204.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.0ms
# Confidence ---> 0.88
# classnamw is  ---> person
# Estimated distance --> 0.7504690431519699 meters
# Speed: 4.8ms preprocess, 169.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 171.7ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 0.7648183556405354 meters
# Speed: 3.9ms preprocess, 171.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.7ms
# Confidence ---> 0.87
# classnamw is  ---> person
# Estimated distance --> 0.7352941176470589 meters
# Speed: 4.4ms preprocess, 191.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.0ms
# Confidence ---> 0.84
# classnamw is  ---> person
# Estimated distance --> 0.7434944237918215 meters
# Speed: 5.1ms preprocess, 169.0ms inference, 14.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.6ms
# Confidence ---> 0.87
# classnamw is  ---> person
# Estimated distance --> 0.7936507936507936 meters
# Speed: 7.0ms preprocess, 168.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 178.0ms
# Confidence ---> 0.87
# classnamw is  ---> person
# Estimated distance --> 0.7259528130671506 meters
# Speed: 0.0ms preprocess, 178.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 188.3ms
# Confidence ---> 0.84
# classnamw is  ---> person
# Estimated distance --> 0.7547169811320755 meters
# Speed: 0.6ms preprocess, 188.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.4ms
# Confidence ---> 0.85
# classnamw is  ---> person
# Estimated distance --> 0.7518796992481203 meters
# Speed: 0.0ms preprocess, 165.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.9ms
# Confidence ---> 0.84
# classnamw is  ---> person
# Estimated distance --> 0.74487895716946 meters
# Speed: 2.2ms preprocess, 174.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.2ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 0.8163265306122449 meters
# Speed: 0.0ms preprocess, 175.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.0ms
# Confidence ---> 0.93
# classnamw is  ---> person
# Estimated distance --> 0.7677543186180422 meters
# Speed: 11.2ms preprocess, 199.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 188.7ms
# Confidence ---> 0.92
# classnamw is  ---> person
# Estimated distance --> 0.8 meters
# Speed: 2.2ms preprocess, 188.7ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 170.4ms
# Confidence ---> 0.94
# classnamw is  ---> person
# Estimated distance --> 0.7299270072992701 meters
# Speed: 0.0ms preprocess, 170.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.1ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 0.7207207207207207 meters
# Speed: 5.6ms preprocess, 177.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.1ms
# Confidence ---> 0.92
# classnamw is  ---> person
# Estimated distance --> 0.718132854578097 meters
# Speed: 4.2ms preprocess, 175.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.1ms
# Confidence ---> 0.92
# classnamw is  ---> person
# Estimated distance --> 0.718132854578097 meters
# Speed: 1.6ms preprocess, 169.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.9ms
# Confidence ---> 0.94
# classnamw is  ---> person
# Estimated distance --> 0.7142857142857143 meters
# Speed: 0.0ms preprocess, 160.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 171.7ms
# Confidence ---> 0.9
# classnamw is  ---> person
# Estimated distance --> 0.7104795737122558 meters
# Speed: 0.5ms preprocess, 171.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 157.3ms
# Confidence ---> 0.88
# classnamw is  ---> person
# Estimated distance --> 0.7194244604316546 meters
# Speed: 0.0ms preprocess, 157.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.3ms
# Confidence ---> 0.89
# classnamw is  ---> person
# Estimated distance --> 0.8888888888888888 meters
# Speed: 0.0ms preprocess, 191.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.6ms
# Confidence ---> 0.92
# classnamw is  ---> person
# Estimated distance --> 1.1204481792717087 meters
# Speed: 0.0ms preprocess, 168.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.4ms
# Confidence ---> 0.92
# classnamw is  ---> person
# Estimated distance --> 1.2422360248447204 meters
# Speed: 0.0ms preprocess, 190.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 157.7ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 1.3071895424836601 meters
# Speed: 0.0ms preprocess, 157.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.3ms
# Confidence ---> 0.9
# classnamw is  ---> person
# Estimated distance --> 1.4035087719298245 meters
# Speed: 0.0ms preprocess, 184.3ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 172.5ms
# Confidence ---> 0.9
# classnamw is  ---> person
# Estimated distance --> 1.3793103448275863 meters
# Speed: 3.9ms preprocess, 172.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 167.1ms
# Confidence ---> 0.89
# classnamw is  ---> person
# Estimated distance --> 1.3114754098360655 meters
# Speed: 1.8ms preprocess, 167.1ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 160.8ms
# Confidence ---> 0.89
# classnamw is  ---> person
# Estimated distance --> 1.4234875444839858 meters
# Speed: 0.0ms preprocess, 160.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 176.0ms
# Confidence ---> 0.93
# classnamw is  ---> person
# Estimated distance --> 1.4705882352941178 meters
# Speed: 0.0ms preprocess, 176.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 176.9ms
# Confidence ---> 0.93
# classnamw is  ---> person
# Estimated distance --> 1.4981273408239701 meters
# Speed: 0.0ms preprocess, 176.9ms inference, 12.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 184.8ms
# Confidence ---> 0.9
# classnamw is  ---> person
# Estimated distance --> 1.5037593984962405 meters
# Speed: 0.0ms preprocess, 184.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 167.9ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 1.4492753623188406 meters
# Speed: 0.0ms preprocess, 167.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 1 dining table, 155.5ms
# Confidence ---> 0.89
# classnamw is  ---> person
# Estimated distance --> 1.5151515151515151 meters
# Speed: 0.0ms preprocess, 155.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 171.7ms
# Confidence ---> 0.87
# classnamw is  ---> person
# Estimated distance --> 1.6260162601626016 meters
# Speed: 1.6ms preprocess, 171.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 173.1ms
# Confidence ---> 0.89
# classnamw is  ---> person
# Estimated distance --> 1.6528925619834711 meters
# Speed: 0.0ms preprocess, 173.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 173.9ms
# Confidence ---> 0.88
# classnamw is  ---> person
# Estimated distance --> 1.6528925619834711 meters
# Speed: 0.0ms preprocess, 173.9ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 161.1ms
# Confidence ---> 0.85
# classnamw is  ---> person
# Estimated distance --> 1.694915254237288 meters
# Speed: 3.3ms preprocess, 161.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 1 bed, 169.6ms
# Confidence ---> 0.81
# classnamw is  ---> person
# Estimated distance --> 1.702127659574468 meters
# Speed: 0.0ms preprocess, 169.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 couch, 1 bed, 170.6ms
# Confidence ---> 0.78
# classnamw is  ---> person
# Estimated distance --> 1.6736401673640167 meters
# Confidence ---> 0.43
# classnamw is  ---> person
# Estimated distance --> 1.1661807580174928 meters
# Speed: 3.2ms preprocess, 170.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 couch, 174.3ms
# Confidence ---> 0.82
# classnamw is  ---> person
# Estimated distance --> 1.702127659574468 meters
# Confidence ---> 0.35
# classnamw is  ---> person
# Estimated distance --> 1.146131805157593 meters
# Speed: 0.0ms preprocess, 174.3ms inference, 12.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 174.7ms
# Confidence ---> 0.87
# classnamw is  ---> person
# Estimated distance --> 1.639344262295082 meters
# Speed: 0.0ms preprocess, 174.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 173.5ms
# Confidence ---> 0.86
# classnamw is  ---> person
# Estimated distance --> 1.5873015873015872 meters
# Speed: 0.0ms preprocess, 173.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 175.6ms
# Confidence ---> 0.89
# classnamw is  ---> person
# Estimated distance --> 1.3986013986013985 meters
# Speed: 0.0ms preprocess, 175.6ms inference, 14.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dining table, 174.2ms
# Confidence ---> 0.92
# classnamw is  ---> person
# Estimated distance --> 1.1527377521613833 meters
# Speed: 0.0ms preprocess, 174.2ms inference, 14.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dining table, 175.2ms
# Confidence ---> 0.88
# classnamw is  ---> person
# Estimated distance --> 1.2012012012012012 meters
# Speed: 0.0ms preprocess, 175.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.1ms
# Confidence ---> 0.81
# classnamw is  ---> person
# Estimated distance --> 1.2269938650306749 meters
# Speed: 0.0ms preprocess, 202.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 1 dining table, 179.1ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 1.4285714285714286 meters
# Speed: 2.3ms preprocess, 179.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.5ms
# Confidence ---> 0.93
# classnamw is  ---> person
# Estimated distance --> 1.3745704467353952 meters
# Speed: 3.2ms preprocess, 160.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 156.1ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 1.3114754098360655 meters
# Speed: 2.8ms preprocess, 156.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 176.1ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 1.1019283746556474 meters
# Speed: 2.9ms preprocess, 176.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.9ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 1.0582010582010581 meters
# Speed: 4.4ms preprocess, 178.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.8ms
# Confidence ---> 0.93
# classnamw is  ---> person
# Estimated distance --> 1.0 meters
# Speed: 2.8ms preprocess, 172.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dining table, 168.1ms
# Confidence ---> 0.92
# classnamw is  ---> person
# Estimated distance --> 0.9876543209876543 meters
# Speed: 2.1ms preprocess, 168.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 155.4ms
# Confidence ---> 0.93
# classnamw is  ---> person
# Estimated distance --> 0.9302325581395349 meters
# Speed: 2.9ms preprocess, 155.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 159.2ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 0.8421052631578947 meters
# Speed: 0.0ms preprocess, 159.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.5ms
# Confidence ---> 0.92
# classnamw is  ---> person
# Estimated distance --> 0.8080808080808081 meters
# Speed: 5.1ms preprocess, 165.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.2ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 0.8368200836820083 meters
# Speed: 0.0ms preprocess, 169.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 185.5ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 0.8810572687224669 meters
# Speed: 2.2ms preprocess, 185.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 187.3ms
# Confidence ---> 0.89
# classnamw is  ---> person
# Estimated distance --> 0.9029345372460497 meters
# Speed: 1.8ms preprocess, 187.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.5ms
# Confidence ---> 0.88
# classnamw is  ---> person
# Estimated distance --> 0.8830022075055187 meters
# Speed: 3.3ms preprocess, 200.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 185.5ms
# Confidence ---> 0.89
# classnamw is  ---> person
# Estimated distance --> 0.8928571428571429 meters
# Speed: 0.0ms preprocess, 185.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 159.0ms
# Confidence ---> 0.9
# classnamw is  ---> person
# Estimated distance --> 0.9111617312072893 meters
# Speed: 1.1ms preprocess, 159.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.5ms
# Confidence ---> 0.9
# classnamw is  ---> person
# Estimated distance --> 0.9070294784580499 meters
# Speed: 1.5ms preprocess, 173.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.4ms
# Confidence ---> 0.88
# classnamw is  ---> person
# Estimated distance --> 0.89086859688196 meters
# Speed: 2.5ms preprocess, 172.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 156.9ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 0.8733624454148472 meters
# Speed: 0.0ms preprocess, 156.9ms inference, 14.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 170.2ms
# Confidence ---> 0.9
# classnamw is  ---> person
# Estimated distance --> 0.8639308855291576 meters
# Speed: 2.3ms preprocess, 170.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.1ms
# Confidence ---> 0.9
# classnamw is  ---> person
# Estimated distance --> 0.8213552361396304 meters
# Speed: 2.9ms preprocess, 172.1ms inference, 13.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.4ms
# Confidence ---> 0.91
# classnamw is  ---> person
# Estimated distance --> 0.7936507936507936 meters
# Speed: 0.0ms preprocess, 175.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 157.2ms
# Confidence ---> 0.94
# classnamw is  ---> person
# Estimated distance --> 0.8403361344537815 meters
# Speed: 1.4ms preprocess, 157.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 187.4ms
# Confidence ---> 0.94
# classnamw is  ---> person
# Estimated distance --> 0.8583690987124464 meters
# Speed: 1.4ms preprocess, 187.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.3ms
# Confidence ---> 0.95
# classnamw is  ---> person
# Estimated distance --> 0.8456659619450317 meters
# Speed: 0.0ms preprocess, 175.3ms inference, 14.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 187.4ms
# Confidence ---> 0.93
# classnamw is  ---> person
# Estimated distance --> 0.8385744234800838 meters
# Speed: 3.7ms preprocess, 187.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
